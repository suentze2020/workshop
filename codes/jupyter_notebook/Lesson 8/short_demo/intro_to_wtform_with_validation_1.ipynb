# %%
from flask import Flask, render_template, redirect, url_for
from flask_wtf import FlaskForm
from wtforms import StringField, PasswordField, SubmitField
from wtforms.validators import InputRequired

app = Flask(__name__)
app.config['SECRET_KEY'] = 'thisisasecret'

class LoginForm(FlaskForm):
    username = StringField('Username', validators=[InputRequired()])
    password = PasswordField('Password', validators=[InputRequired()])
    submit = SubmitField('Login')

@app.route('/')
def home():
    return redirect(url_for('form'))
    
@app.route('/login',methods=["POST","GET"])
def form():
    form = LoginForm()
    if form.validate_on_submit():
        print("*** name:",form.username.data)
        return render_template('form.html',form=form, username=form.username.data)
    print("name:",form.username.data)
    return render_template('form.html',form=form)


if __name__ == '__main__':
    app.run('localhost', 9089)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:9089/ (Press CTRL+C to quit)
# 127.0.0.1 - - [25/Oct/2021 13:54:10] "GET / HTTP/1.1" 302 -
# 127.0.0.1 - - [25/Oct/2021 13:54:10] "GET /login HTTP/1.1" 200 -
# name: None
# 127.0.0.1 - - [25/Oct/2021 13:54:18] "POST /login HTTP/1.1" 200 -
# *** name: test3
# 127.0.0.1 - - [25/Oct/2021 13:55:07] "GET /login HTTP/1.1" 200 -
# name: None
